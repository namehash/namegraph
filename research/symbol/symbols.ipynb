# %% [markdown]
# # Symbols mapping

# %% [markdown]
# ## Obtaining all valid symbols

# %%
import myunicode

# %%
from itertools import count

def all_unicode_iterator():
    for code in count(0):
        try:
            chr(code)
        except ValueError:
            return
        
        yield chr(code)

# %%
all_currency_symbols = [char for char in all_unicode_iterator() if myunicode.category(char) == 'Sc']
all_math_symbols     = [char for char in all_unicode_iterator() if myunicode.category(char) == 'Sm']
all_other_symbols    = [char for char in all_unicode_iterator() if myunicode.category(char) == 'So']

# %%
len(all_currency_symbols), len(all_math_symbols), len(all_other_symbols)
# Out:
# (63, 948, 6605)

# %%
def is_normalized(char: str) -> bool:
    try:
        return myunicode.ens_normalize(char) == char
    except ValueError:
        return False

# %%
def is_valid(char: str) -> bool:
    return is_normalized(char) and not myunicode.is_emoji(char)

# %%
valid_currency_symbols = [char for char in all_currency_symbols if is_valid(char)]
valid_math_symbols     = [char for char in all_math_symbols if is_valid(char)]
valid_other_symbols    = [char for char in all_other_symbols if is_valid(char)]

# %%
len(valid_currency_symbols), len(valid_math_symbols), len(valid_other_symbols)
# Out:
# (41, 30, 859)

# %% [markdown]
# ## Math and Currencies mapping made by hand

# %%
for symb in valid_currency_symbols:
    print(f"{repr(symb)}: [{repr(myunicode.name(symb))}]")

print()

for symb in valid_math_symbols:
    print(f"{repr(symb)}: [{repr(myunicode.name(symb))}]")
# Out:
# '$': ['DOLLAR SIGN']
# '¢': ['CENT SIGN']
# '£': ['POUND SIGN']
# '¤': ['CURRENCY SIGN']
# '¥': ['YEN SIGN']
# '֏': ['ARMENIAN DRAM SIGN']
# '؋': ['AFGHANI SIGN']
# '߾': ['NKO DOROME SIGN']
# '߿': ['NKO TAMAN SIGN']
# '৲': ['BENGALI RUPEE MARK']
# '৳': ['BENGALI RUPEE SIGN']
# '৻': ['BENGALI GANDA MARK']
# '૱': ['GUJARATI RUPEE SIGN']
# '௹': ['TAMIL RUPEE SIGN']
# '฿': ['THAI CURRENCY SYMBOL BAHT']
# '៛': ['KHMER CURRENCY SYMBOL RIEL']
# '₡': ['COLON SIGN']
# '₦': ['NAIRA SIGN']
# '₩': ['WON SIGN']
# '₪': ['NEW SHEQEL SIGN']
# '₫': ['DONG SIGN']
# '€': ['EURO SIGN']
# '₭': ['KIP SIGN']
# '₮': ['TUGRIK SIGN']
# '₱': ['PESO SIGN']
# '₲': ['GUARANI SIGN']
# '₴': ['HRYVNIA SIGN']
# '₵': ['CEDI SIGN']
# '₸': ['TENGE SIGN']
# '₹': ['INDIAN RUPEE SIGN']
# '₺': ['TURKISH LIRA SIGN']
# '₼': ['MANAT SIGN']
# '₽': ['RUBLE SIGN']
# '₾': ['LARI SIGN']
# '₿': ['BITCOIN SIGN']
# '\u20c0': ['SOM SIGN']
# '𑿝': ['TAMIL SIGN KAACU']
# '𑿞': ['TAMIL SIGN PANAM']
# '𑿟': ['TAMIL SIGN PON']
# ...

# %%
currency_mapping = {
    '$': ['DOLLAR'],
    '¢': ['CENT'],
    '£': ['POUND'],
    '¤': ['CURRENCY'],
    '¥': ['YEN'],
    '֏': ['DRAM'],
    '؋': ['AFGHANI'],
    '߾': ['DOROME'],
    '߿': ['TAMAN'],
    '৲': ['RUPEE'],
    '৳': ['RUPEE'],
    '৻': ['GANDA'],
    '૱': ['RUPEE'],
    '௹': ['RUPEE'],
    '฿': ['BAHT'],
    '៛': ['RIEL'],
    '₠': ['EURO'],
    '₡': ['COLON'],
    '₢': ['CRUZEIRO'],
    '₣': ['FRANC'],
    '₤': ['LIRA'],
    '₥': ['MILL'],
    '₦': ['NAIRA'],
    '₧': ['PESETA'],
    '₩': ['WON'],
    '₪': ['SHEQEL'],
    '₫': ['DONG'],
    '€': ['EURO'],
    '₭': ['KIP'],
    '₮': ['TUGRIK'],
    '₯': ['DRACHMA'],
    '₰': ['PENNY'],
    '₱': ['PESO'],
    '₲': ['GUARANI'],
    '₳': ['AUSTRAL'],
    '₴': ['HRYVNIA'],
    '₵': ['CEDI'],
    '₶': ['LIVRE TOURNOIS SIGN'], #
    '₷': ['SPESMILO'],
    '₸': ['TENGE'],
    '₹': ['RUPEE'],
    '₺': ['LIRA'],
    '₻': ['NORDIC MARK SIGN'], #
    '₼': ['MANAT'],
    '₽': ['RUBLE'],
    '₾': ['LARI'],
    '₿': ['BITCOIN'],
    '\u20c0': ['SOM'],
    '꠸': ['RUPEE'],
    '𑿝': ['KAACU'],
    '𑿞': ['PANAM'],
    '𑿟': ['PON'],
    '𑿠': ['VARAAKAN'],
    '𞋿': ['WANCHO NGUN SIGN'], #
    '𞲰': ['INDIC SIYAQ RUPEE MARK'], #
}

# %%
math_mapping = {
    '¬': ['NOT', 'NEGATION'],
    '±': ['PLUS-MINUS', 'UNCERTAINTY', 'ERROR'],  # ??
    '∓': ['MINUS-PLUS'], # ??
    '϶': ['EPSILON'],
    '؆': ['ROOT'],
    '؇': ['ROOT'],
    '؈': ['RAY'],
    '⁄': ['FRACTION'],
    '℘': ['P'],
    
    '←': ['LEFTWARDS', 'LEFT', 'ARROW'],
    '↑': ['UPWARDS', 'UP', 'ARROW'],
    '→': ['RIGHTWARDS', 'RIGHT', 'ARROW'],
    '↓': ['DOWNWARDS', 'DOWN', 'ARROW'],
#     '↚': ['LEFTWARDS', 'ARROW', 'STROKE'], # ??
#     '↛': ['RIGHTWARDS', 'ARROW', 'STROKE'], # ??
#     '↠': ['RIGHTWARDS', 'ARROW'], # ??
#     '↣': ['RIGHTWARDS', 'ARROW'], # ??
#     '↦': ['RIGHTWARDS', 'ARROW'], # ??
#     '↮': ['ARROW', 'STROKE'], # ??
#     '⇎': ['ARROW', 'STROKE'], #
#     '⇏': ['RIGHTWARDS', 'ARROW', 'STROKE'], # ??
#     '⇒': ['RIGHTWARDS', 'RIGHT', 'ARROW'],
    '⇔': ['ARROW', 'BIDIRECTIONAL', 'DUPLEX'],
#     '⇴': ['ARROW'], # ??
    '⇵': ['ARROW', 'BIDIRECTIONAL', 'DUPLEX', 'ALTERNATING', 'SWAP', 'EXCHANGE'],
#     '⇶': ['THREE RIGHTWARDS ARROWS'], #
#     '⇷': ['LEFTWARDS', 'ARROW', 'STROKE'],
#     '⇸': ['RIGHTWARDS', 'ARROW', 'STROKE'],
#     '⇹': ['LEFT RIGHT ARROW WITH VERTICAL STROKE'], #
#     '⇺': ['LEFTWARDS ARROW WITH DOUBLE VERTICAL STROKE'], #
#     '⇻': ['RIGHTWARDS ARROW WITH DOUBLE VERTICAL STROKE'], #
#     '⇼': ['LEFT RIGHT ARROW WITH DOUBLE VERTICAL STROKE'], #
#     '⇽': ['LEFTWARDS OPEN-HEADED ARROW'], #
#     '⇾': ['RIGHTWARDS OPEN-HEADED ARROW'], #
#     '⇿': ['LEFT RIGHT OPEN-HEADED ARROW'], #
#     '⟰': ['UPWARDS', 'ARROW'],
#     '⟱': ['DOWNWARDS', 'ARROW'],
#     '⬰': ['LEFT ARROW WITH SMALL CIRCLE'], #
#     '⬱': ['THREE LEFTWARDS ARROWS'], #
#     '⬲': ['LEFT ARROW WITH CIRCLED PLUS'], #
#     '⬳': ['LONG LEFTWARDS SQUIGGLE ARROW'], #
#     '⬴': ['LEFTWARDS TWO-HEADED ARROW WITH VERTICAL STROKE'], #
#     '⬵': ['LEFTWARDS TWO-HEADED ARROW WITH DOUBLE VERTICAL STROKE'], #
#     '⬶': ['LEFTWARDS TWO-HEADED ARROW FROM BAR'], #
#     '⬷': ['LEFTWARDS TWO-HEADED TRIPLE DASH ARROW'], #
#     '⬸': ['LEFTWARDS ARROW WITH DOTTED STEM'], #
#     '⬹': ['LEFTWARDS ARROW WITH TAIL WITH VERTICAL STROKE'], #
#     '⬺': ['LEFTWARDS ARROW WITH TAIL WITH DOUBLE VERTICAL STROKE'], #
#     '⬻': ['LEFTWARDS TWO-HEADED ARROW WITH TAIL'], #
#     '⬼': ['LEFTWARDS TWO-HEADED ARROW WITH TAIL WITH VERTICAL STROKE'], #
#     '⬽': ['LEFTWARDS TWO-HEADED ARROW WITH TAIL WITH DOUBLE VERTICAL STROKE'], #
#     '⬾': ['LEFTWARDS ARROW THROUGH X'], #
    '⬿': ['WAVE ARROW POINTING DIRECTLY LEFT'],
#     '⭀': ['EQUALS SIGN ABOVE LEFTWARDS ARROW'], #
#     '⭁': ['REVERSE TILDE OPERATOR ABOVE LEFTWARDS ARROW'], #
#     '⭂': ['LEFTWARDS ARROW ABOVE REVERSE ALMOST EQUAL TO'], #
#     '⭃': ['RIGHTWARDS ARROW THROUGH GREATER-THAN'], #
#     '⭄': ['RIGHTWARDS ARROW THROUGH SUPERSET'], #
#     '⭇': ['REVERSE TILDE OPERATOR ABOVE RIGHTWARDS ARROW'], #
#     '⭈': ['RIGHTWARDS ARROW ABOVE REVERSE ALMOST EQUAL TO'], #
#     '⭉': ['TILDE OPERATOR ABOVE LEFTWARDS ARROW'], #
#     '⭊': ['LEFTWARDS ARROW ABOVE ALMOST EQUAL TO'], #

    
    '∀': ['FORALL', 'ALL', 'EVERY'],
    '∂': ['DIFFERENTIAL', 'DERIVATIVE'],
    '∏': ['PRODUCT'],
    '∐': ['COPRODUCT'],
    '∑': ['SUMMATION', 'SUM', 'SIGMA'],
    '√': ['ROOT', 'SQRT'],
    '∝': ['PROPORTIONAL'],
    '∞': ['INFINITY'],
    '∫': ['INTEGRAL'],
    '∮': ['CONTOUR', 'INTEGRAL'], # CONTOUR?
    '≋': ['TILDE'],
    '⊕': ['PLUS'],
    '⊖': ['MINUS'],
    '⊗': ['TIMES'],
    '⊘': ['DIVISION'],
    '⊙': ['DOT'],
    '⊚': ['RING'],
    '⊛': ['ASTERISK'],
    '⊜': ['EQUALS'],
    '⊝': ['DASH'],
    '⊞': ['PLUS'],
    '⊟': ['MINUS'],
    '⊠': ['TIMES'],
    '⊡': ['DOT'],
    
    '⊶': ['ORIGINAL'],
    '⊷': ['IMAGE'],
    '⋈': ['BOWTIE'],
    '▷': ['RIGHT', 'TRIANGLE'],
    '◁': ['LEFT', 'TRIANGLE'],
    '◸': ['UPPERLEFT', 'TRIANGLE'],
    '◹': ['UPPERRIGHT', 'TRIANGLE'],
    '◺': ['LOWERLEFT', 'TRIANGLE'],
    '◿': ['LOWERRIGHT', 'TRIANGLE'],
    '⟀': ['ANGLE', 'ORIGIN', 'SPACE', 'COORDINATES'],
    '⟁': ['TRIANGLE'],
    '⟂': ['PERPENDICULAR'],

    '⭋': ['LEFTWARDS ARROW ABOVE REVERSE TILDE OPERATOR'], #
    '⭌': ['RIGHTWARDS ARROW ABOVE REVERSE TILDE OPERATOR'], #
    '𞻰': ['ARABIC MATHEMATICAL OPERATOR MEEM WITH HAH WITH TATWEEL'], #
    '𞻱': ['ARABIC MATHEMATICAL OPERATOR HAH WITH DAL'], #
}

# %% [markdown]
# ## Extracting mapping

# %%
used_symbols = set()

# %% [markdown]
# ### Filtering scripts

# %%
from collections import defaultdict

# %%
all_scripts = set([myunicode.script_of(char) for char in valid_other_symbols])
script2chars = defaultdict(list)
for char in valid_other_symbols:
    script2chars[myunicode.script_of(char)].append(char)

for script, chars in script2chars.items():
    print(script)
    print(*chars)
    print()
# Out:
# Common
# ...

# %%
symbols = script2chars['Common']

# %%
len(symbols)
# Out:
# 525

# %% [markdown]
# ### Extracting all one-word symbols

# %%
def char_name(char: str) -> str:
    return myunicode.name(char)

# %%
one_word_other_symbols = {
    char: char_name(char)
    for char in symbols if len(char_name(char).split()) == 1
}

# %%
len(one_word_other_symbols)
# Out:
# 3

# %%
one_word_other_symbols
# Out:
# {'◉': 'FISHEYE', '◎': 'BULLSEYE', '🥆': 'RIFLE'}

# %%
used_symbols.update(one_word_other_symbols.keys())

# %% [markdown]
# ### Extracting the mapping from the names

# %%
from collections import Counter

import matplotlib.pyplot as plt

# %%
tf = Counter()
other_symbols2tokens = {
    char: char_name(char).split()
    for char in symbols
    if char not in used_symbols
}

# %%
for tokens in other_symbols2tokens.values():
    tf.update(tokens)

# %%
frequencies = [f for _, f in tf.most_common()]

# %%
plt.hist(frequencies, bins=100)
plt.yscale('log')
plt.show()

# %%
tf.most_common()[:100]
# Out:
# [('ARROW', 135),
#  ('ZNAMENNY', 116),
#  ('NEUME', 116),
#  ('BLACK', 98),
#  ('WITH', 66),
#  ('TRIANGLE-HEADED', 57),
#  ('HEAVY', 52),
#  ('RIGHTWARDS', 48),
#  ('SQUARED', 45),
#  ('RIGHT', 41),
#  ('WHITE', 39),
#  ('LEFT', 36),
#  ('STRELA', 34),
#  ('DOWNWARDS', 29),
#  ('NEGATIVE', 29),
#  ('HALF', 27),
#  ('LEFTWARDS', 27),
#  ('LATIN', 25),
#  ('UPWARDS', 25),
#  ('LOWER', 23),
#  ('LETTER', 23),
#  ('CAPITAL', 22),
#  ('AND', 21),
#  ('SQUARE', 20),
#  ('EAST', 20),
#  ('CIRCLE', 19),
#  ('TRIANGLE', 19),
#  ('NORTH', 19),
#  ('STAR', 18),
#  ('UPPER', 17),
#  ('SOUTH', 17),
#  ('POINTED', 15),
#  ('TO', 13),
#  ('DIAMOND', 13),
#  ('ASTERISK', 13),
#  ('TIP', 13),
#  ('SYMBOL', 12),
#  ('FOUR', 12),
#  ('WEST', 12),
#  ('S', 12),
#  ('MEDIUM', 11),
#  ('HORIZONTAL', 11),
#  ('ARROWHEAD', 11),
#  ('KLYUCHEVAYA', 11),
#  ('SKAMEYTSA', 11),
#  ('STATYA', 11),
#  ('KRYUKOVAYA', 11),
#  ('CURVED', 10),
#  ('BAR', 10),
#  ('CROSS', 9),
#  ('WIDE-HEADED', 9),
# ...

# %%
# stop_words = set(['SIGN', 'SYMBOL', 'TIBETAN', 'KHMER', ''])
for symbol, tokens in other_symbols2tokens.items():
    if symbol in used_symbols:
        continue
        
    sorted_tokens = sorted(tokens, key=lambda x: tf[x])
    print(f"{repr(symbol)}: [{', '.join(map(repr, sorted_tokens))}],  # {myunicode.name(symbol)}")
# Out:
# '°': ['DEGREE', 'SIGN'],  # DEGREE SIGN
# '℗': ['SOUND', 'RECORDING', 'COPYRIGHT'],  # SOUND RECORDING COPYRIGHT
# '℞': ['PRESCRIPTION', 'TAKE'],  # PRESCRIPTION TAKE
# '↯': ['ZIGZAG', 'DOWNWARDS', 'ARROW'],  # DOWNWARDS ZIGZAG ARROW
# '⌁': ['ELECTRIC', 'ARROW'],  # ELECTRIC ARROW
# '⌇': ['WAVY', 'LINE'],  # WAVY LINE
# '⌐': ['NOT', 'REVERSED', 'SIGN'],  # REVERSED NOT SIGN
# '⌕': ['RECORDER', 'TELEPHONE'],  # TELEPHONE RECORDER
# '⌖': ['POSITION', 'INDICATOR'],  # POSITION INDICATOR
# '⌘': ['PLACE', 'INTEREST', 'OF', 'SIGN'],  # PLACE OF INTEREST SIGN
# '⌥': ['OPTION', 'KEY'],  # OPTION KEY
# '⌦': ['ERASE', 'THE', 'TO', 'RIGHT'],  # ERASE TO THE RIGHT
# '⌫': ['ERASE', 'THE', 'TO', 'LEFT'],  # ERASE TO THE LEFT
# '⌬': ['BENZENE', 'RING'],  # BENZENE RING
# '⍾': ['BELL', 'SYMBOL'],  # BELL SYMBOL
# '⎆': ['ENTER', 'SYMBOL'],  # ENTER SYMBOL
# '⎇': ['ALTERNATIVE', 'KEY', 'SYMBOL'],  # ALTERNATIVE KEY SYMBOL
# ...

# %%
from openpyxl.workbook import Workbook
from openpyxl.utils import get_column_letter

# %%
wb = Workbook()
ws = wb.create_sheet(title='other')

for symbol, tokens in other_symbols2tokens.items():
    if symbol in used_symbols:
        continue
    
    symbol_name = myunicode.name(symbol).lower()
    sorted_tokens = list(map(lambda x: x.lower(), sorted(set(tokens), key=lambda x: tf[x])))
    ws.append([symbol_name, symbol, ''] + sorted_tokens)

wb.save('symbols.xlsx')

# %%
other_mapping = {
    '°': ['DEGREE', 'SIGN'],  # DEGREE SIGN
    '℗': ['SOUND', 'RECORDING', 'COPYRIGHT'],  # SOUND RECORDING COPYRIGHT
    '℞': ['PRESCRIPTION', 'TAKE'],  # PRESCRIPTION TAKE
    '↯': ['ZIGZAG', 'DOWNWARDS', 'ARROW'],  # DOWNWARDS ZIGZAG ARROW
    '⌁': ['ELECTRIC', 'ARROW'],  # ELECTRIC ARROW
    '⌇': ['WAVY', 'LINE'],  # WAVY LINE
    '⌐': ['NOT', 'REVERSED', 'SIGN'],  # REVERSED NOT SIGN
    '⌕': ['RECORDER', 'TELEPHONE'],  # TELEPHONE RECORDER
    '⌖': ['POSITION', 'INDICATOR'],  # POSITION INDICATOR
    '⌘': ['PLACE', 'INTEREST', 'OF', 'SIGN'],  # PLACE OF INTEREST SIGN
    '⌥': ['OPTION', 'KEY'],  # OPTION KEY
    '⌦': ['ERASE', 'THE', 'TO', 'RIGHT'],  # ERASE TO THE RIGHT
    '⌫': ['ERASE', 'THE', 'TO', 'LEFT'],  # ERASE TO THE LEFT
    '⌬': ['BENZENE', 'RING'],  # BENZENE RING
    '⍾': ['BELL', 'SYMBOL'],  # BELL SYMBOL
    '⎆': ['ENTER', 'SYMBOL'],  # ENTER SYMBOL
    '⎇': ['ALTERNATIVE', 'KEY', 'SYMBOL'],  # ALTERNATIVE KEY SYMBOL
    '⎖': ['DECIMAL', 'SEPARATOR', 'KEY', 'SYMBOL'],  # DECIMAL SEPARATOR KEY SYMBOL
    '⎙': ['PRINT', 'SCREEN', 'SYMBOL'],  # PRINT SCREEN SYMBOL
    '⏎': ['RETURN', 'SYMBOL'],  # RETURN SYMBOL
    '⏚': ['EARTH', 'GROUND'],  # EARTH GROUND
    '⏣': ['BENZENE', 'RING', 'CIRCLE', 'WITH'],  # BENZENE RING WITH CIRCLE
    '⏴': ['LEFT-POINTING', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM LEFT-POINTING TRIANGLE
    '⏵': ['RIGHT-POINTING', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM RIGHT-POINTING TRIANGLE
    '⏶': ['UP-POINTING', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM UP-POINTING TRIANGLE
    '⏷': ['DOWN-POINTING', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM DOWN-POINTING TRIANGLE
    '⏻': ['POWER', 'SYMBOL'],  # POWER SYMBOL
    '⏿': ['OBSERVER', 'EYE', 'SYMBOL'],  # OBSERVER EYE SYMBOL
    '▁': ['EIGHTH', 'ONE', 'BLOCK', 'LOWER'],  # LOWER ONE EIGHTH BLOCK
    '▂': ['QUARTER', 'ONE', 'BLOCK', 'LOWER'],  # LOWER ONE QUARTER BLOCK
    '▃': ['EIGHTHS', 'THREE', 'BLOCK', 'LOWER'],  # LOWER THREE EIGHTHS BLOCK
    '▄': ['BLOCK', 'LOWER', 'HALF'],  # LOWER HALF BLOCK
    '▅': ['EIGHTHS', 'FIVE', 'BLOCK', 'LOWER'],  # LOWER FIVE EIGHTHS BLOCK
    '▆': ['QUARTERS', 'THREE', 'BLOCK', 'LOWER'],  # LOWER THREE QUARTERS BLOCK
    '▇': ['SEVEN', 'EIGHTHS', 'BLOCK', 'LOWER'],  # LOWER SEVEN EIGHTHS BLOCK
    '█': ['FULL', 'BLOCK'],  # FULL BLOCK
    '░': ['LIGHT', 'SHADE'],  # LIGHT SHADE
    '▒': ['SHADE', 'MEDIUM'],  # MEDIUM SHADE
    '▓': ['DARK', 'SHADE'],  # DARK SHADE
    '▙': ['QUADRANT', 'UPPER', 'AND', 'AND', 'LOWER', 'LOWER', 'LEFT', 'LEFT', 'RIGHT'],  # QUADRANT UPPER LEFT AND LOWER LEFT AND LOWER RIGHT
    '▚': ['QUADRANT', 'UPPER', 'AND', 'LOWER', 'LEFT', 'RIGHT'],  # QUADRANT UPPER LEFT AND LOWER RIGHT
    '▛': ['QUADRANT', 'UPPER', 'UPPER', 'AND', 'AND', 'LOWER', 'LEFT', 'LEFT', 'RIGHT'],  # QUADRANT UPPER LEFT AND UPPER RIGHT AND LOWER LEFT
    '▜': ['QUADRANT', 'UPPER', 'UPPER', 'AND', 'AND', 'LOWER', 'LEFT', 'RIGHT', 'RIGHT'],  # QUADRANT UPPER LEFT AND UPPER RIGHT AND LOWER RIGHT
    '▞': ['QUADRANT', 'UPPER', 'AND', 'LOWER', 'LEFT', 'RIGHT'],  # QUADRANT UPPER RIGHT AND LOWER LEFT
    '▟': ['QUADRANT', 'UPPER', 'AND', 'AND', 'LOWER', 'LOWER', 'LEFT', 'RIGHT', 'RIGHT'],  # QUADRANT UPPER RIGHT AND LOWER LEFT AND LOWER RIGHT
    '▣': ['CONTAINING', 'SMALL', 'SQUARE', 'SQUARE', 'WHITE', 'BLACK'],  # WHITE SQUARE CONTAINING BLACK SMALL SQUARE
    '▤': ['FILL', 'HORIZONTAL', 'SQUARE', 'WITH'],  # SQUARE WITH HORIZONTAL FILL
    '▥': ['VERTICAL', 'FILL', 'SQUARE', 'WITH'],  # SQUARE WITH VERTICAL FILL
    '▦': ['ORTHOGONAL', 'CROSSHATCH', 'FILL', 'SQUARE', 'WITH'],  # SQUARE WITH ORTHOGONAL CROSSHATCH FILL
    '▧': ['FILL', 'TO', 'UPPER', 'SQUARE', 'LOWER', 'LEFT', 'RIGHT', 'WITH'],  # SQUARE WITH UPPER LEFT TO LOWER RIGHT FILL
    '▨': ['FILL', 'TO', 'UPPER', 'SQUARE', 'LOWER', 'LEFT', 'RIGHT', 'WITH'],  # SQUARE WITH UPPER RIGHT TO LOWER LEFT FILL
    '▩': ['CROSSHATCH', 'DIAGONAL', 'FILL', 'SQUARE', 'WITH'],  # SQUARE WITH DIAGONAL CROSSHATCH FILL
    '▰': ['PARALLELOGRAM', 'BLACK'],  # BLACK PARALLELOGRAM
    '▱': ['PARALLELOGRAM', 'WHITE'],  # WHITE PARALLELOGRAM
    '▲': ['UP-POINTING', 'TRIANGLE', 'BLACK'],  # BLACK UP-POINTING TRIANGLE
    '△': ['UP-POINTING', 'TRIANGLE', 'WHITE'],  # WHITE UP-POINTING TRIANGLE
    '▼': ['DOWN-POINTING', 'TRIANGLE', 'BLACK'],  # BLACK DOWN-POINTING TRIANGLE
    '▽': ['DOWN-POINTING', 'TRIANGLE', 'WHITE'],  # WHITE DOWN-POINTING TRIANGLE
    '◆': ['DIAMOND', 'BLACK'],  # BLACK DIAMOND
    '◈': ['CONTAINING', 'SMALL', 'DIAMOND', 'DIAMOND', 'WHITE', 'BLACK'],  # WHITE DIAMOND CONTAINING BLACK SMALL DIAMOND
    '◍': ['VERTICAL', 'FILL', 'CIRCLE', 'WITH'],  # CIRCLE WITH VERTICAL FILL
    '◐': ['CIRCLE', 'HALF', 'LEFT', 'WITH', 'BLACK'],  # CIRCLE WITH LEFT HALF BLACK
    '◑': ['CIRCLE', 'HALF', 'RIGHT', 'WITH', 'BLACK'],  # CIRCLE WITH RIGHT HALF BLACK
    '◒': ['CIRCLE', 'LOWER', 'HALF', 'WITH', 'BLACK'],  # CIRCLE WITH LOWER HALF BLACK
    '◓': ['UPPER', 'CIRCLE', 'HALF', 'WITH', 'BLACK'],  # CIRCLE WITH UPPER HALF BLACK
    '◔': ['QUADRANT', 'UPPER', 'CIRCLE', 'RIGHT', 'WITH', 'BLACK'],  # CIRCLE WITH UPPER RIGHT QUADRANT BLACK
    '◕': ['ALL', 'BUT', 'QUADRANT', 'UPPER', 'CIRCLE', 'LEFT', 'WITH', 'BLACK'],  # CIRCLE WITH ALL BUT UPPER LEFT QUADRANT BLACK
    '◖': ['CIRCLE', 'HALF', 'LEFT', 'BLACK'],  # LEFT HALF BLACK CIRCLE
    '◗': ['CIRCLE', 'HALF', 'RIGHT', 'BLACK'],  # RIGHT HALF BLACK CIRCLE
    '◢': ['TRIANGLE', 'LOWER', 'RIGHT', 'BLACK'],  # BLACK LOWER RIGHT TRIANGLE
    '◣': ['TRIANGLE', 'LOWER', 'LEFT', 'BLACK'],  # BLACK LOWER LEFT TRIANGLE
    '◤': ['UPPER', 'TRIANGLE', 'LEFT', 'BLACK'],  # BLACK UPPER LEFT TRIANGLE
    '◥': ['UPPER', 'TRIANGLE', 'RIGHT', 'BLACK'],  # BLACK UPPER RIGHT TRIANGLE
    '◧': ['SQUARE', 'HALF', 'LEFT', 'WITH', 'BLACK'],  # SQUARE WITH LEFT HALF BLACK
    '◨': ['SQUARE', 'HALF', 'RIGHT', 'WITH', 'BLACK'],  # SQUARE WITH RIGHT HALF BLACK
    '◩': ['DIAGONAL', 'UPPER', 'SQUARE', 'HALF', 'LEFT', 'WITH', 'BLACK'],  # SQUARE WITH UPPER LEFT DIAGONAL HALF BLACK
    '◪': ['DIAGONAL', 'SQUARE', 'LOWER', 'HALF', 'RIGHT', 'WITH', 'BLACK'],  # SQUARE WITH LOWER RIGHT DIAGONAL HALF BLACK
    '◫': ['BISECTING', 'LINE', 'VERTICAL', 'SQUARE', 'WHITE', 'WITH'],  # WHITE SQUARE WITH VERTICAL BISECTING LINE
    '◬': ['DOT', 'UP-POINTING', 'TRIANGLE', 'WHITE', 'WITH'],  # WHITE UP-POINTING TRIANGLE WITH DOT
    '◭': ['UP-POINTING', 'TRIANGLE', 'HALF', 'LEFT', 'WITH', 'BLACK'],  # UP-POINTING TRIANGLE WITH LEFT HALF BLACK
    '◮': ['UP-POINTING', 'TRIANGLE', 'HALF', 'RIGHT', 'WITH', 'BLACK'],  # UP-POINTING TRIANGLE WITH RIGHT HALF BLACK
    '◯': ['LARGE', 'CIRCLE'],  # LARGE CIRCLE
    '☆': ['STAR', 'WHITE'],  # WHITE STAR
    '✆': ['LOCATION', 'TELEPHONE', 'SIGN'],  # TELEPHONE LOCATION SIGN
    '✇': ['TAPE', 'DRIVE'],  # TAPE DRIVE
    '✘': ['BALLOT', 'X', 'HEAVY'],  # HEAVY BALLOT X
    '✚': ['GREEK', 'CROSS', 'HEAVY'],  # HEAVY GREEK CROSS
    '✜': ['CENTRE', 'OPEN', 'CROSS', 'HEAVY'],  # HEAVY OPEN CENTRE CROSS
    '✞': ['SHADOWED', 'CROSS', 'LATIN', 'WHITE'],  # SHADOWED WHITE LATIN CROSS
    '✟': ['OUTLINED', 'CROSS', 'LATIN'],  # OUTLINED LATIN CROSS
    '✠': ['MALTESE', 'CROSS'],  # MALTESE CROSS
    '✢': ['TEARDROP-SPOKED', 'FOUR', 'ASTERISK'],  # FOUR TEARDROP-SPOKED ASTERISK
    '✤': ['BALLOON-SPOKED', 'FOUR', 'ASTERISK', 'HEAVY'],  # HEAVY FOUR BALLOON-SPOKED ASTERISK
    '✥': ['CLUB-SPOKED', 'FOUR', 'ASTERISK'],  # FOUR CLUB-SPOKED ASTERISK
    '✦': ['FOUR', 'POINTED', 'STAR', 'BLACK'],  # BLACK FOUR POINTED STAR
    '✧': ['FOUR', 'POINTED', 'STAR', 'WHITE'],  # WHITE FOUR POINTED STAR
    '✩': ['STRESS', 'OUTLINED', 'STAR', 'WHITE'],  # STRESS OUTLINED WHITE STAR
    '✪': ['CIRCLED', 'STAR', 'WHITE'],  # CIRCLED WHITE STAR
    '✫': ['CENTRE', 'OPEN', 'STAR', 'BLACK'],  # OPEN CENTRE BLACK STAR
    '✬': ['CENTRE', 'STAR', 'WHITE', 'BLACK'],  # BLACK CENTRE WHITE STAR
    '✮': ['OUTLINED', 'STAR', 'HEAVY', 'BLACK'],  # HEAVY OUTLINED BLACK STAR
    '✯': ['PINWHEEL', 'STAR'],  # PINWHEEL STAR
    '✰': ['SHADOWED', 'STAR', 'WHITE'],  # SHADOWED WHITE STAR
    '✱': ['ASTERISK', 'HEAVY'],  # HEAVY ASTERISK
    '✲': ['CENTRE', 'OPEN', 'ASTERISK'],  # OPEN CENTRE ASTERISK
    '✶': ['SIX', 'POINTED', 'STAR', 'BLACK'],  # SIX POINTED BLACK STAR
    '✸': ['RECTILINEAR', 'EIGHT', 'POINTED', 'STAR', 'HEAVY', 'BLACK'],  # HEAVY EIGHT POINTED RECTILINEAR BLACK STAR
    '✹': ['TWELVE', 'POINTED', 'STAR', 'BLACK'],  # TWELVE POINTED BLACK STAR
    '✺': ['SIXTEEN', 'ASTERISK', 'POINTED'],  # SIXTEEN POINTED ASTERISK
    '✽': ['TEARDROP-SPOKED', 'ASTERISK', 'HEAVY'],  # HEAVY TEARDROP-SPOKED ASTERISK
    '✾': ['PETALLED', 'SIX', 'FLORETTE', 'AND', 'WHITE', 'BLACK'],  # SIX PETALLED BLACK AND WHITE FLORETTE
    '✿': ['FLORETTE', 'BLACK'],  # BLACK FLORETTE
    '❀': ['FLORETTE', 'WHITE'],  # WHITE FLORETTE
    '❁': ['PETALLED', 'OUTLINED', 'FLORETTE', 'EIGHT', 'BLACK'],  # EIGHT PETALLED OUTLINED BLACK FLORETTE
    '❂': ['CENTRE', 'EIGHT', 'OPEN', 'CIRCLED', 'POINTED', 'STAR'],  # CIRCLED OPEN CENTRE EIGHT POINTED STAR
    '❃': ['PINWHEEL', 'TEARDROP-SPOKED', 'ASTERISK', 'HEAVY'],  # HEAVY TEARDROP-SPOKED PINWHEEL ASTERISK
    '❅': ['TIGHT', 'TRIFOLIATE', 'SNOWFLAKE'],  # TIGHT TRIFOLIATE SNOWFLAKE
    '❆': ['CHEVRON', 'SNOWFLAKE', 'HEAVY'],  # HEAVY CHEVRON SNOWFLAKE
    '❈': ['SPARKLE', 'HEAVY'],  # HEAVY SPARKLE
    '❉': ['BALLOON-SPOKED', 'ASTERISK'],  # BALLOON-SPOKED ASTERISK
    '❋': ['PROPELLER', 'TEARDROP-SPOKED', 'EIGHT', 'ASTERISK', 'HEAVY'],  # HEAVY EIGHT TEARDROP-SPOKED PROPELLER ASTERISK
    '❖': ['MINUS', 'X', 'DIAMOND', 'WHITE', 'BLACK'],  # BLACK DIAMOND MINUS WHITE X
    '➔': ['WIDE-HEADED', 'RIGHTWARDS', 'HEAVY', 'ARROW'],  # HEAVY WIDE-HEADED RIGHTWARDS ARROW
    '➘': ['SOUTH', 'EAST', 'HEAVY', 'ARROW'],  # HEAVY SOUTH EAST ARROW
    '➙': ['RIGHTWARDS', 'HEAVY', 'ARROW'],  # HEAVY RIGHTWARDS ARROW
    '➚': ['NORTH', 'EAST', 'HEAVY', 'ARROW'],  # HEAVY NORTH EAST ARROW
    '➛': ['DRAFTING', 'POINT', 'RIGHTWARDS', 'ARROW'],  # DRAFTING POINT RIGHTWARDS ARROW
    '➜': ['ROUND-TIPPED', 'RIGHTWARDS', 'HEAVY', 'ARROW'],  # HEAVY ROUND-TIPPED RIGHTWARDS ARROW
    '➝': ['RIGHTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # TRIANGLE-HEADED RIGHTWARDS ARROW
    '➞': ['RIGHTWARDS', 'HEAVY', 'TRIANGLE-HEADED', 'ARROW'],  # HEAVY TRIANGLE-HEADED RIGHTWARDS ARROW
    '➟': ['DASHED', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # DASHED TRIANGLE-HEADED RIGHTWARDS ARROW
    '➠': ['DASHED', 'RIGHTWARDS', 'HEAVY', 'TRIANGLE-HEADED', 'ARROW'],  # HEAVY DASHED TRIANGLE-HEADED RIGHTWARDS ARROW
    '➢': ['TOP-LIGHTED', 'THREE-D', 'ARROWHEAD', 'RIGHTWARDS'],  # THREE-D TOP-LIGHTED RIGHTWARDS ARROWHEAD
    '➣': ['BOTTOM-LIGHTED', 'THREE-D', 'ARROWHEAD', 'RIGHTWARDS'],  # THREE-D BOTTOM-LIGHTED RIGHTWARDS ARROWHEAD
    '➤': ['ARROWHEAD', 'RIGHTWARDS', 'BLACK'],  # BLACK RIGHTWARDS ARROWHEAD
    '➥': ['CURVED', 'AND', 'DOWNWARDS', 'RIGHTWARDS', 'HEAVY', 'BLACK', 'ARROW'],  # HEAVY BLACK CURVED DOWNWARDS AND RIGHTWARDS ARROW
    '➦': ['CURVED', 'AND', 'UPWARDS', 'RIGHTWARDS', 'HEAVY', 'BLACK', 'ARROW'],  # HEAVY BLACK CURVED UPWARDS AND RIGHTWARDS ARROW
    '➧': ['SQUAT', 'RIGHTWARDS', 'BLACK', 'ARROW'],  # SQUAT BLACK RIGHTWARDS ARROW
    '➨': ['CONCAVE-POINTED', 'RIGHTWARDS', 'HEAVY', 'BLACK', 'ARROW'],  # HEAVY CONCAVE-POINTED BLACK RIGHTWARDS ARROW
    '➲': ['CIRCLED', 'WHITE', 'RIGHTWARDS', 'HEAVY', 'ARROW'],  # CIRCLED HEAVY WHITE RIGHTWARDS ARROW
    '➳': ['WHITE-FEATHERED', 'RIGHTWARDS', 'ARROW'],  # WHITE-FEATHERED RIGHTWARDS ARROW
    '➴': ['BLACK-FEATHERED', 'SOUTH', 'EAST', 'ARROW'],  # BLACK-FEATHERED SOUTH EAST ARROW
    '➵': ['BLACK-FEATHERED', 'RIGHTWARDS', 'ARROW'],  # BLACK-FEATHERED RIGHTWARDS ARROW
    '➶': ['BLACK-FEATHERED', 'NORTH', 'EAST', 'ARROW'],  # BLACK-FEATHERED NORTH EAST ARROW
    '➷': ['BLACK-FEATHERED', 'SOUTH', 'EAST', 'HEAVY', 'ARROW'],  # HEAVY BLACK-FEATHERED SOUTH EAST ARROW
    '➸': ['BLACK-FEATHERED', 'RIGHTWARDS', 'HEAVY', 'ARROW'],  # HEAVY BLACK-FEATHERED RIGHTWARDS ARROW
    '➹': ['BLACK-FEATHERED', 'NORTH', 'EAST', 'HEAVY', 'ARROW'],  # HEAVY BLACK-FEATHERED NORTH EAST ARROW
    '➺': ['TEARDROP-BARBED', 'RIGHTWARDS', 'ARROW'],  # TEARDROP-BARBED RIGHTWARDS ARROW
    '➻': ['TEARDROP-SHANKED', 'RIGHTWARDS', 'HEAVY', 'ARROW'],  # HEAVY TEARDROP-SHANKED RIGHTWARDS ARROW
    '➼': ['WEDGE-TAILED', 'RIGHTWARDS', 'ARROW'],  # WEDGE-TAILED RIGHTWARDS ARROW
    '➽': ['WEDGE-TAILED', 'RIGHTWARDS', 'HEAVY', 'ARROW'],  # HEAVY WEDGE-TAILED RIGHTWARDS ARROW
    '⬀': ['NORTH', 'EAST', 'WHITE', 'ARROW'],  # NORTH EAST WHITE ARROW
    '⬁': ['WEST', 'NORTH', 'WHITE', 'ARROW'],  # NORTH WEST WHITE ARROW
    '⬂': ['SOUTH', 'EAST', 'WHITE', 'ARROW'],  # SOUTH EAST WHITE ARROW
    '⬃': ['WEST', 'SOUTH', 'WHITE', 'ARROW'],  # SOUTH WEST WHITE ARROW
    '⬄': ['LEFT', 'WHITE', 'RIGHT', 'ARROW'],  # LEFT RIGHT WHITE ARROW
    '⬈': ['NORTH', 'EAST', 'BLACK', 'ARROW'],  # NORTH EAST BLACK ARROW
    '⬉': ['WEST', 'NORTH', 'BLACK', 'ARROW'],  # NORTH WEST BLACK ARROW
    '⬊': ['SOUTH', 'EAST', 'BLACK', 'ARROW'],  # SOUTH EAST BLACK ARROW
    '⬋': ['WEST', 'SOUTH', 'BLACK', 'ARROW'],  # SOUTH WEST BLACK ARROW
    '⬌': ['LEFT', 'RIGHT', 'BLACK', 'ARROW'],  # LEFT RIGHT BLACK ARROW
    '⬍': ['UP', 'DOWN', 'BLACK', 'ARROW'],  # UP DOWN BLACK ARROW
    '⬎': ['TIP', 'DOWNWARDS', 'RIGHTWARDS', 'WITH', 'ARROW'],  # RIGHTWARDS ARROW WITH TIP DOWNWARDS
    '⬏': ['TIP', 'UPWARDS', 'RIGHTWARDS', 'WITH', 'ARROW'],  # RIGHTWARDS ARROW WITH TIP UPWARDS
    '⬐': ['TIP', 'LEFTWARDS', 'DOWNWARDS', 'WITH', 'ARROW'],  # LEFTWARDS ARROW WITH TIP DOWNWARDS
    '⬑': ['TIP', 'UPWARDS', 'LEFTWARDS', 'WITH', 'ARROW'],  # LEFTWARDS ARROW WITH TIP UPWARDS
    '⬒': ['TOP', 'SQUARE', 'HALF', 'WITH', 'BLACK'],  # SQUARE WITH TOP HALF BLACK
    '⬓': ['BOTTOM', 'SQUARE', 'HALF', 'WITH', 'BLACK'],  # SQUARE WITH BOTTOM HALF BLACK
    '⬔': ['DIAGONAL', 'UPPER', 'SQUARE', 'HALF', 'RIGHT', 'WITH', 'BLACK'],  # SQUARE WITH UPPER RIGHT DIAGONAL HALF BLACK
    '⬕': ['DIAGONAL', 'SQUARE', 'LOWER', 'HALF', 'LEFT', 'WITH', 'BLACK'],  # SQUARE WITH LOWER LEFT DIAGONAL HALF BLACK
    '⬖': ['DIAMOND', 'HALF', 'LEFT', 'WITH', 'BLACK'],  # DIAMOND WITH LEFT HALF BLACK
    '⬗': ['DIAMOND', 'HALF', 'RIGHT', 'WITH', 'BLACK'],  # DIAMOND WITH RIGHT HALF BLACK
    '⬘': ['TOP', 'DIAMOND', 'HALF', 'WITH', 'BLACK'],  # DIAMOND WITH TOP HALF BLACK
    '⬙': ['BOTTOM', 'DIAMOND', 'HALF', 'WITH', 'BLACK'],  # DIAMOND WITH BOTTOM HALF BLACK
    '⬚': ['DOTTED', 'SQUARE'],  # DOTTED SQUARE
    '⬟': ['PENTAGON', 'BLACK'],  # BLACK PENTAGON
    '⬠': ['PENTAGON', 'WHITE'],  # WHITE PENTAGON
    '⬡': ['HEXAGON', 'WHITE'],  # WHITE HEXAGON
    '⬢': ['HEXAGON', 'BLACK'],  # BLACK HEXAGON
    '⬣': ['HEXAGON', 'HORIZONTAL', 'BLACK'],  # HORIZONTAL BLACK HEXAGON
    '⬤': ['LARGE', 'CIRCLE', 'BLACK'],  # BLACK LARGE CIRCLE
    '⬥': ['MEDIUM', 'DIAMOND', 'BLACK'],  # BLACK MEDIUM DIAMOND
    '⬦': ['MEDIUM', 'DIAMOND', 'WHITE'],  # WHITE MEDIUM DIAMOND
    '⬩': ['SMALL', 'DIAMOND', 'BLACK'],  # BLACK SMALL DIAMOND
    '⬮': ['ELLIPSE', 'VERTICAL', 'BLACK'],  # BLACK VERTICAL ELLIPSE
    '⭅': ['QUADRUPLE', 'LEFTWARDS', 'ARROW'],  # LEFTWARDS QUADRUPLE ARROW
    '⭆': ['QUADRUPLE', 'RIGHTWARDS', 'ARROW'],  # RIGHTWARDS QUADRUPLE ARROW
    '⭍': ['ZIGZAG', 'DOWNWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED ZIGZAG ARROW
    '⭖': ['OVAL', 'OVAL', 'INSIDE', 'HEAVY', 'WITH'],  # HEAVY OVAL WITH OVAL INSIDE
    '⭗': ['INSIDE', 'CIRCLE', 'CIRCLE', 'HEAVY', 'WITH'],  # HEAVY CIRCLE WITH CIRCLE INSIDE
    '⭚': ['HEAD', 'SLANTED', 'HOOKED', 'NORTH', 'WITH', 'ARROW'],  # SLANTED NORTH ARROW WITH HOOKED HEAD
    '⭛': ['BACKSLANTED', 'HOOKED', 'TAIL', 'SOUTH', 'WITH', 'ARROW'],  # BACKSLANTED SOUTH ARROW WITH HOOKED TAIL
    '⭜': ['SLANTED', 'TAIL', 'HORIZONTAL', 'NORTH', 'WITH', 'ARROW'],  # SLANTED NORTH ARROW WITH HORIZONTAL TAIL
    '⭝': ['BACKSLANTED', 'TAIL', 'HORIZONTAL', 'SOUTH', 'WITH', 'ARROW'],  # BACKSLANTED SOUTH ARROW WITH HORIZONTAL TAIL
    '⭞': ['BENT', 'THEN', 'POINTING', 'NORTH', 'EAST', 'DOWNWARDS', 'ARROW'],  # BENT ARROW POINTING DOWNWARDS THEN NORTH EAST
    '⭟': ['SHORT', 'BENT', 'THEN', 'POINTING', 'NORTH', 'EAST', 'DOWNWARDS', 'ARROW'],  # SHORT BENT ARROW POINTING DOWNWARDS THEN NORTH EAST
    '⭠': ['LEFTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # LEFTWARDS TRIANGLE-HEADED ARROW
    '⭡': ['UPWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # UPWARDS TRIANGLE-HEADED ARROW
    '⭢': ['RIGHTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # RIGHTWARDS TRIANGLE-HEADED ARROW
    '⭣': ['DOWNWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED ARROW
    '⭤': ['LEFT', 'RIGHT', 'TRIANGLE-HEADED', 'ARROW'],  # LEFT RIGHT TRIANGLE-HEADED ARROW
    '⭥': ['UP', 'DOWN', 'TRIANGLE-HEADED', 'ARROW'],  # UP DOWN TRIANGLE-HEADED ARROW
    '⭦': ['WEST', 'NORTH', 'TRIANGLE-HEADED', 'ARROW'],  # NORTH WEST TRIANGLE-HEADED ARROW
    '⭧': ['NORTH', 'EAST', 'TRIANGLE-HEADED', 'ARROW'],  # NORTH EAST TRIANGLE-HEADED ARROW
    '⭨': ['SOUTH', 'EAST', 'TRIANGLE-HEADED', 'ARROW'],  # SOUTH EAST TRIANGLE-HEADED ARROW
    '⭩': ['WEST', 'SOUTH', 'TRIANGLE-HEADED', 'ARROW'],  # SOUTH WEST TRIANGLE-HEADED ARROW
    '⭪': ['DASHED', 'LEFTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # LEFTWARDS TRIANGLE-HEADED DASHED ARROW
    '⭫': ['DASHED', 'UPWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # UPWARDS TRIANGLE-HEADED DASHED ARROW
    '⭬': ['DASHED', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # RIGHTWARDS TRIANGLE-HEADED DASHED ARROW
    '⭭': ['DASHED', 'DOWNWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED DASHED ARROW
    '⭮': ['CLOCKWISE', 'OPEN', 'CIRCLE', 'TRIANGLE-HEADED', 'ARROW'],  # CLOCKWISE TRIANGLE-HEADED OPEN CIRCLE ARROW
    '⭯': ['ANTICLOCKWISE', 'OPEN', 'CIRCLE', 'TRIANGLE-HEADED', 'ARROW'],  # ANTICLOCKWISE TRIANGLE-HEADED OPEN CIRCLE ARROW
    '⭰': ['BAR', 'TO', 'LEFTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # LEFTWARDS TRIANGLE-HEADED ARROW TO BAR
    '⭱': ['BAR', 'TO', 'UPWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # UPWARDS TRIANGLE-HEADED ARROW TO BAR
    '⭲': ['BAR', 'TO', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # RIGHTWARDS TRIANGLE-HEADED ARROW TO BAR
    '⭳': ['BAR', 'TO', 'DOWNWARDS', 'TRIANGLE-HEADED', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED ARROW TO BAR
    '⭶': ['BAR', 'WEST', 'TO', 'NORTH', 'TRIANGLE-HEADED', 'ARROW'],  # NORTH WEST TRIANGLE-HEADED ARROW TO BAR
    '⭷': ['BAR', 'TO', 'NORTH', 'EAST', 'TRIANGLE-HEADED', 'ARROW'],  # NORTH EAST TRIANGLE-HEADED ARROW TO BAR
    '⭸': ['BAR', 'TO', 'SOUTH', 'EAST', 'TRIANGLE-HEADED', 'ARROW'],  # SOUTH EAST TRIANGLE-HEADED ARROW TO BAR
    '⭹': ['BAR', 'WEST', 'TO', 'SOUTH', 'TRIANGLE-HEADED', 'ARROW'],  # SOUTH WEST TRIANGLE-HEADED ARROW TO BAR
    '⭺': ['STROKE', 'DOUBLE', 'HORIZONTAL', 'LEFTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # LEFTWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE
    '⭻': ['STROKE', 'DOUBLE', 'HORIZONTAL', 'UPWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # UPWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE
    '⭼': ['STROKE', 'DOUBLE', 'HORIZONTAL', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # RIGHTWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE
    '⭽': ['STROKE', 'DOUBLE', 'HORIZONTAL', 'DOWNWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED ARROW WITH DOUBLE HORIZONTAL STROKE
    '⭾': ['TAB', 'KEY', 'HORIZONTAL'],  # HORIZONTAL TAB KEY
    '⭿': ['TAB', 'VERTICAL', 'KEY'],  # VERTICAL TAB KEY
    '⮀': ['OVER', 'LEFTWARDS', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'TRIANGLE-HEADED', 'ARROW', 'ARROW'],  # LEFTWARDS TRIANGLE-HEADED ARROW OVER RIGHTWARDS TRIANGLE-HEADED ARROW
    '⮁': ['OF', 'UPWARDS', 'LEFTWARDS', 'DOWNWARDS', 'TRIANGLE-HEADED', 'TRIANGLE-HEADED', 'ARROW', 'ARROW'],  # UPWARDS TRIANGLE-HEADED ARROW LEFTWARDS OF DOWNWARDS TRIANGLE-HEADED ARROW
    '⮂': ['OVER', 'LEFTWARDS', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'TRIANGLE-HEADED', 'ARROW', 'ARROW'],  # RIGHTWARDS TRIANGLE-HEADED ARROW OVER LEFTWARDS TRIANGLE-HEADED ARROW
    '⮃': ['OF', 'UPWARDS', 'LEFTWARDS', 'DOWNWARDS', 'TRIANGLE-HEADED', 'TRIANGLE-HEADED', 'ARROW', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED ARROW LEFTWARDS OF UPWARDS TRIANGLE-HEADED ARROW
    '⮄': ['PAIRED', 'ARROWS', 'LEFTWARDS', 'TRIANGLE-HEADED'],  # LEFTWARDS TRIANGLE-HEADED PAIRED ARROWS
    '⮅': ['PAIRED', 'ARROWS', 'UPWARDS', 'TRIANGLE-HEADED'],  # UPWARDS TRIANGLE-HEADED PAIRED ARROWS
    '⮆': ['PAIRED', 'ARROWS', 'RIGHTWARDS', 'TRIANGLE-HEADED'],  # RIGHTWARDS TRIANGLE-HEADED PAIRED ARROWS
    '⮇': ['PAIRED', 'ARROWS', 'DOWNWARDS', 'TRIANGLE-HEADED'],  # DOWNWARDS TRIANGLE-HEADED PAIRED ARROWS
    '⮈': ['CIRCLED', 'LEFTWARDS', 'WHITE', 'BLACK', 'ARROW'],  # LEFTWARDS BLACK CIRCLED WHITE ARROW
    '⮉': ['CIRCLED', 'UPWARDS', 'WHITE', 'BLACK', 'ARROW'],  # UPWARDS BLACK CIRCLED WHITE ARROW
    '⮊': ['CIRCLED', 'WHITE', 'RIGHTWARDS', 'BLACK', 'ARROW'],  # RIGHTWARDS BLACK CIRCLED WHITE ARROW
    '⮋': ['CIRCLED', 'DOWNWARDS', 'WHITE', 'BLACK', 'ARROW'],  # DOWNWARDS BLACK CIRCLED WHITE ARROW
    '⮌': ['U-SHAPED', 'ANTICLOCKWISE', 'RIGHT', 'TRIANGLE-HEADED', 'ARROW'],  # ANTICLOCKWISE TRIANGLE-HEADED RIGHT U-SHAPED ARROW
    '⮍': ['BOTTOM', 'U-SHAPED', 'ANTICLOCKWISE', 'TRIANGLE-HEADED', 'ARROW'],  # ANTICLOCKWISE TRIANGLE-HEADED BOTTOM U-SHAPED ARROW
    '⮎': ['U-SHAPED', 'ANTICLOCKWISE', 'LEFT', 'TRIANGLE-HEADED', 'ARROW'],  # ANTICLOCKWISE TRIANGLE-HEADED LEFT U-SHAPED ARROW
    '⮏': ['TOP', 'U-SHAPED', 'ANTICLOCKWISE', 'TRIANGLE-HEADED', 'ARROW'],  # ANTICLOCKWISE TRIANGLE-HEADED TOP U-SHAPED ARROW
    '⮐': ['RETURN', 'LEFT'],  # RETURN LEFT
    '⮑': ['RETURN', 'RIGHT'],  # RETURN RIGHT
    '⮒': ['NEWLINE', 'LEFT'],  # NEWLINE LEFT
    '⮓': ['NEWLINE', 'RIGHT'],  # NEWLINE RIGHT
    '⮔': ['CORNER', 'CIRCLING', 'ARROWS', 'ANTICLOCKWISE', 'FOUR'],  # FOUR CORNER ARROWS CIRCLING ANTICLOCKWISE
    '⮕': ['RIGHTWARDS', 'BLACK', 'ARROW'],  # RIGHTWARDS BLACK ARROW
    '⮗': ['FOR', 'TYPE', 'A', 'ELECTRONICS', 'SYMBOL'],  # SYMBOL FOR TYPE A ELECTRONICS
    '⮘': ['TOP-LIGHTED', 'THREE-D', 'EQUILATERAL', 'ARROWHEAD', 'LEFTWARDS'],  # THREE-D TOP-LIGHTED LEFTWARDS EQUILATERAL ARROWHEAD
    '⮙': ['RIGHT-LIGHTED', 'THREE-D', 'EQUILATERAL', 'ARROWHEAD', 'UPWARDS'],  # THREE-D RIGHT-LIGHTED UPWARDS EQUILATERAL ARROWHEAD
    '⮚': ['TOP-LIGHTED', 'THREE-D', 'EQUILATERAL', 'ARROWHEAD', 'RIGHTWARDS'],  # THREE-D TOP-LIGHTED RIGHTWARDS EQUILATERAL ARROWHEAD
    '⮛': ['LEFT-LIGHTED', 'THREE-D', 'EQUILATERAL', 'ARROWHEAD', 'DOWNWARDS'],  # THREE-D LEFT-LIGHTED DOWNWARDS EQUILATERAL ARROWHEAD
    '⮜': ['EQUILATERAL', 'ARROWHEAD', 'LEFTWARDS', 'BLACK'],  # BLACK LEFTWARDS EQUILATERAL ARROWHEAD
    '⮝': ['EQUILATERAL', 'ARROWHEAD', 'UPWARDS', 'BLACK'],  # BLACK UPWARDS EQUILATERAL ARROWHEAD
    '⮞': ['EQUILATERAL', 'ARROWHEAD', 'RIGHTWARDS', 'BLACK'],  # BLACK RIGHTWARDS EQUILATERAL ARROWHEAD
    '⮟': ['EQUILATERAL', 'ARROWHEAD', 'DOWNWARDS', 'BLACK'],  # BLACK DOWNWARDS EQUILATERAL ARROWHEAD
    '⮠': ['LONG', 'TIP', 'LEFTWARDS', 'DOWNWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED ARROW WITH LONG TIP LEFTWARDS
    '⮡': ['LONG', 'TIP', 'DOWNWARDS', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # DOWNWARDS TRIANGLE-HEADED ARROW WITH LONG TIP RIGHTWARDS
    '⮢': ['LONG', 'TIP', 'UPWARDS', 'LEFTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # UPWARDS TRIANGLE-HEADED ARROW WITH LONG TIP LEFTWARDS
    '⮣': ['LONG', 'TIP', 'UPWARDS', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # UPWARDS TRIANGLE-HEADED ARROW WITH LONG TIP RIGHTWARDS
    '⮤': ['LONG', 'TIP', 'UPWARDS', 'LEFTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # LEFTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP UPWARDS
    '⮥': ['LONG', 'TIP', 'UPWARDS', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # RIGHTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP UPWARDS
    '⮦': ['LONG', 'TIP', 'LEFTWARDS', 'DOWNWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # LEFTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP DOWNWARDS
    '⮧': ['LONG', 'TIP', 'DOWNWARDS', 'RIGHTWARDS', 'TRIANGLE-HEADED', 'WITH', 'ARROW'],  # RIGHTWARDS TRIANGLE-HEADED ARROW WITH LONG TIP DOWNWARDS
    '⮨': ['CURVED', 'AND', 'LEFTWARDS', 'DOWNWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED DOWNWARDS AND LEFTWARDS ARROW
    '⮩': ['CURVED', 'AND', 'DOWNWARDS', 'RIGHTWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED DOWNWARDS AND RIGHTWARDS ARROW
    '⮪': ['CURVED', 'AND', 'UPWARDS', 'LEFTWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED UPWARDS AND LEFTWARDS ARROW
    '⮫': ['CURVED', 'AND', 'UPWARDS', 'RIGHTWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED UPWARDS AND RIGHTWARDS ARROW
    '⮬': ['CURVED', 'AND', 'UPWARDS', 'LEFTWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED LEFTWARDS AND UPWARDS ARROW
    '⮭': ['CURVED', 'AND', 'UPWARDS', 'RIGHTWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED RIGHTWARDS AND UPWARDS ARROW
    '⮮': ['CURVED', 'AND', 'LEFTWARDS', 'DOWNWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED LEFTWARDS AND DOWNWARDS ARROW
    '⮯': ['CURVED', 'AND', 'DOWNWARDS', 'RIGHTWARDS', 'BLACK', 'ARROW'],  # BLACK CURVED RIGHTWARDS AND DOWNWARDS ARROW
    '⮰': ['DOWN', 'RIBBON', 'LEFT', 'ARROW'],  # RIBBON ARROW DOWN LEFT
    '⮱': ['DOWN', 'RIBBON', 'RIGHT', 'ARROW'],  # RIBBON ARROW DOWN RIGHT
    '⮲': ['UP', 'RIBBON', 'LEFT', 'ARROW'],  # RIBBON ARROW UP LEFT
    '⮳': ['UP', 'RIBBON', 'RIGHT', 'ARROW'],  # RIBBON ARROW UP RIGHT
    '⮴': ['UP', 'RIBBON', 'LEFT', 'ARROW'],  # RIBBON ARROW LEFT UP
    '⮵': ['UP', 'RIBBON', 'RIGHT', 'ARROW'],  # RIBBON ARROW RIGHT UP
    '⮶': ['DOWN', 'RIBBON', 'LEFT', 'ARROW'],  # RIBBON ARROW LEFT DOWN
    '⮷': ['DOWN', 'RIBBON', 'RIGHT', 'ARROW'],  # RIBBON ARROW RIGHT DOWN
    '⮸': ['FROM', 'BAR', 'BAR', 'HORIZONTAL', 'UPWARDS', 'WHITE', 'WITH', 'ARROW'],  # UPWARDS WHITE ARROW FROM BAR WITH HORIZONTAL BAR
    '⯀': ['CENTRED', 'SQUARE', 'BLACK'],  # BLACK SQUARE CENTRED
    '⯁': ['CENTRED', 'DIAMOND', 'BLACK'],  # BLACK DIAMOND CENTRED
    '⯃': ['OCTAGON', 'HORIZONTAL', 'BLACK'],  # HORIZONTAL BLACK OCTAGON
    '⯄': ['OCTAGON', 'BLACK'],  # BLACK OCTAGON
    '⯅': ['CENTRED', 'UP-POINTING', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM UP-POINTING TRIANGLE CENTRED
    '⯆': ['DOWN-POINTING', 'CENTRED', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM DOWN-POINTING TRIANGLE CENTRED
    '⯇': ['LEFT-POINTING', 'CENTRED', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM LEFT-POINTING TRIANGLE CENTRED
    '⯈': ['RIGHT-POINTING', 'CENTRED', 'MEDIUM', 'TRIANGLE', 'BLACK'],  # BLACK MEDIUM RIGHT-POINTING TRIANGLE CENTRED
    '⯉': ['NEPTUNE', 'FORM', 'TWO'],  # NEPTUNE FORM TWO
    '⯊': ['TOP', 'CIRCLE', 'HALF', 'BLACK'],  # TOP HALF BLACK CIRCLE
    '⯋': ['BOTTOM', 'CIRCLE', 'HALF', 'BLACK'],  # BOTTOM HALF BLACK CIRCLE
    '⯌': ['LIGHT', 'CUSP', 'FOUR', 'POINTED', 'BLACK'],  # LIGHT FOUR POINTED BLACK CUSP
    '⯍': ['ROTATED', 'LIGHT', 'CUSP', 'FOUR', 'POINTED', 'BLACK'],  # ROTATED LIGHT FOUR POINTED BLACK CUSP
    '⯎': ['CUSP', 'FOUR', 'POINTED', 'WHITE'],  # WHITE FOUR POINTED CUSP
    '⯏': ['ROTATED', 'CUSP', 'FOUR', 'POINTED', 'WHITE'],  # ROTATED WHITE FOUR POINTED CUSP
    '⯐': ['POSITION', 'INDICATOR', 'SQUARE'],  # SQUARE POSITION INDICATOR
    '〄': ['JAPANESE', 'INDUSTRIAL', 'STANDARD', 'SYMBOL'],  # JAPANESE INDUSTRIAL STANDARD SYMBOL
    '〓': ['GETA', 'MARK'],  # GETA MARK
    '〠': ['POSTAL', 'FACE', 'MARK'],  # POSTAL MARK FACE
    '㉿': ['KOREAN', 'STANDARD', 'SYMBOL'],  # KOREAN STANDARD SYMBOL
    '\U0001cf50': ['KRYUK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME KRYUK
    '\U0001cf51': ['KRYUK', 'TIKHY', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME KRYUK TIKHY
    '\U0001cf52': ['PARAKLIT', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME PARAKLIT
    '\U0001cf53': ['DVA', 'CHELNU', 'V', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME DVA V CHELNU
    '\U0001cf54': ['KLYUCH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME KLYUCH
    '\U0001cf55': ['ZANOZHEK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME ZANOZHEK
    '\U0001cf56': ['STOPITSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STOPITSA
    '\U0001cf57': ['OCHKOM', 'STOPITSA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STOPITSA S OCHKOM
    '\U0001cf58': ['PEREVODKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME PEREVODKA
    '\U0001cf59': ['PEREVODKA', 'NEPOSTOYANNAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME PEREVODKA NEPOSTOYANNAYA
    '\U0001cf5a': ['SOROCHYA', 'NOZHKA', 'STOPITSA', 'WITH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STOPITSA WITH SOROCHYA NOZHKA
    '\U0001cf5b': ['CHELYUSTKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME CHELYUSTKA
    '\U0001cf5c': ['PALKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME PALKA
    '\U0001cf5d': ['ZAPYATAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME ZAPYATAYA
    '\U0001cf5e': ['BORZY', 'GOLUBCHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME GOLUBCHIK BORZY
    '\U0001cf5f': ['TIKHY', 'GOLUBCHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME GOLUBCHIK TIKHY
    '\U0001cf60': ['MRACHNY', 'GOLUBCHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME GOLUBCHIK MRACHNY
    '\U0001cf61': ['SVETLY', 'GOLUBCHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME GOLUBCHIK SVETLY
    '\U0001cf62': ['TRESVETLY', 'GOLUBCHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME GOLUBCHIK TRESVETLY
    '\U0001cf63': ['PROSTAYA', 'VRAKHIYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA PROSTAYA
    '\U0001cf64': ['MRACHNAYA', 'VRAKHIYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA MRACHNAYA
    '\U0001cf65': ['VRAKHIYA', 'SVETLAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA SVETLAYA
    '\U0001cf66': ['TRESVETLAYA', 'VRAKHIYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA TRESVETLAYA
    '\U0001cf67': ['PROSTAYA', 'VRAKHIYA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA KLYUCHEVAYA PROSTAYA
    '\U0001cf68': ['MRACHNAYA', 'VRAKHIYA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA KLYUCHEVAYA MRACHNAYA
    '\U0001cf69': ['VRAKHIYA', 'SVETLAYA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA KLYUCHEVAYA SVETLAYA
    '\U0001cf6a': ['TRESVETLAYA', 'VRAKHIYA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME VRAKHIYA KLYUCHEVAYA TRESVETLAYA
    '\U0001cf6b': ['DOUBLE', 'ZAPYATAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME DOUBLE ZAPYATAYA
    '\U0001cf6c': ['REVERSED', 'CHELYUSTKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME REVERSED CHELYUSTKA
    '\U0001cf6d': ['DERBITSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME DERBITSA
    '\U0001cf6e': ['KHAMILO', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME KHAMILO
    '\U0001cf6f': ['CHASHKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME CHASHKA
    '\U0001cf70': ['PODCHASHIE', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME PODCHASHIE
    '\U0001cf71': ['MRACHNAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA MRACHNAYA
    '\U0001cf72': ['SVETLAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA SVETLAYA
    '\U0001cf73': ['TRESVETLAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA TRESVETLAYA
    '\U0001cf74': ['TIKHAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA TIKHAYA
    '\U0001cf75': ['DEMESTVENNY', 'KLYUCH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME DEMESTVENNY KLYUCH
    '\U0001cf76': ['SVETLAYA', 'SKAMEYTSA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA KLYUCHEVAYA SVETLAYA
    '\U0001cf77': ['KLYUCHENEPOSTOYANNAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA KLYUCHENEPOSTOYANNAYA
    '\U0001cf78': ['TIKHAYA', 'SKAMEYTSA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA KLYUCHEVAYA TIKHAYA
    '\U0001cf79': ['PROSTAYA', 'DVOECHELNAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA DVOECHELNAYA PROSTAYA
    '\U0001cf7a': ['DVOECHELNAYA', 'SVETLAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA DVOECHELNAYA SVETLAYA
    '\U0001cf7b': ['NEPOSTOYANNAYA', 'DVOECHELNAYA', 'SKAMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA DVOECHELNAYA NEPOSTOYANNAYA
    '\U0001cf7c': ['DVOECHELNAYA', 'SKAMEYTSA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SKAMEYTSA DVOECHELNAYA KLYUCHEVAYA
    '\U0001cf7d': ['SLOZHITIE', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SLOZHITIE
    '\U0001cf7e': ['SLOZHITIE', 'ZAPYATOY', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SLOZHITIE S ZAPYATOY
    '\U0001cf7f': ['ZAKRYTOE', 'SLOZHITIE', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SLOZHITIE ZAKRYTOE
    '\U0001cf80': ['SLOZHITIE', 'KRYZHEM', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME SLOZHITIE S KRYZHEM
    '\U0001cf81': ['KRYZH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME KRYZH
    '\U0001cf82': ['ROG', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME ROG
    '\U0001cf83': ['FITA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME FITA
    '\U0001cf84': ['KOBYLA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME KOBYLA
    '\U0001cf85': ['ZMEYTSA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME ZMEYTSA
    '\U0001cf86': ['STATYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA
    '\U0001cf87': ['ZAPYATOY', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA S ZAPYATOY
    '\U0001cf88': ['KRYZHEM', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA S KRYZHEM
    '\U0001cf89': ['I', 'KRYZHEM', 'ZAPYATOY', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA S ZAPYATOY I KRYZHEM
    '\U0001cf8a': ['KRYZHEM', 'I', 'ZAPYATOY', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA S KRYZHEM I ZAPYATOY
    '\U0001cf8b': ['ZAKRYTAYA', 'STATYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA ZAKRYTAYA
    '\U0001cf8c': ['ZAKRYTAYA', 'ZAPYATOY', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA ZAKRYTAYA S ZAPYATOY
    '\U0001cf8d': ['ROGOM', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA S ROGOM
    '\U0001cf8e': ['DVUMYA', 'ZAPYATYMI', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA S DVUMYA ZAPYATYMI
    '\U0001cf8f': ['PODCHASHIEM', 'I', 'ZAPYATOY', 'STATYA', 'S', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA S ZAPYATOY I PODCHASHIEM
    '\U0001cf90': ['POLKULIZMY', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME POLKULIZMY
    '\U0001cf91': ['NEPOSTOYANNAYA', 'STATYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STATYA NEPOSTOYANNAYA
    '\U0001cf92': ['PROSTAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA PROSTAYA
    '\U0001cf93': ['MRACHNOTIKHAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA MRACHNOTIKHAYA
    '\U0001cf94': ['KRYZHEVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYZHEVAYA
    '\U0001cf95': ['POLUPOVODNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA POLUPOVODNAYA
    '\U0001cf96': ['POVODNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA POVODNAYA
    '\U0001cf97': ['NEPOSTOYANNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA NEPOSTOYANNAYA
    '\U0001cf98': ['KLYUCHEPOVODNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KLYUCHEPOVODNAYA
    '\U0001cf99': ['KLYUCHENEPOSTOYANNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KLYUCHENEPOSTOYANNAYA
    '\U0001cf9a': ['PUTNAYA', 'TIKHAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA TIKHAYA PUTNAYA
    '\U0001cf9b': ['DVOECHELNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA DVOECHELNAYA
    '\U0001cf9c': ['DVOECHELNOKRYZHEVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA DVOECHELNOKRYZHEVAYA
    '\U0001cf9d': ['DVOECHELNOPOVODNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA DVOECHELNOPOVODNAYA
    '\U0001cf9e': ['DVOECHELNAYA', 'KLYUCHEVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA DVOECHELNAYA KLYUCHEVAYA
    '\U0001cf9f': ['DVOECHELNOPOVODNAYA', 'KLYUCHEVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA DVOECHELNOPOVODNAYA KLYUCHEVAYA
    '\U0001cfa0': ['GROMNAYA', 'SINGLE', 'ZAPYATAYA', 'STRELA', 'WITH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA GROMNAYA WITH SINGLE ZAPYATAYA
    '\U0001cfa1': ['SINGLE', 'GROMOPOVODNAYA', 'ZAPYATAYA', 'STRELA', 'WITH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA GROMOPOVODNAYA WITH SINGLE ZAPYATAYA
    '\U0001cfa2': ['GROMNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA GROMNAYA
    '\U0001cfa3': ['GROMOPOVODNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA GROMOPOVODNAYA
    '\U0001cfa4': ['GROMOPOVODNAYA', 'DOUBLE', 'ZAPYATAYA', 'STRELA', 'WITH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA GROMOPOVODNAYA WITH DOUBLE ZAPYATAYA
    '\U0001cfa5': ['GROMOKRYZHEVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA GROMOKRYZHEVAYA
    '\U0001cfa6': ['GROMOKRYZHEVAYA', 'POVODNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA GROMOKRYZHEVAYA POVODNAYA
    '\U0001cfa7': ['MECHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME MECHIK
    '\U0001cfa8': ['POVODNY', 'MECHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME MECHIK POVODNY
    '\U0001cfa9': ['KLYUCHEVOY', 'MECHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME MECHIK KLYUCHEVOY
    '\U0001cfaa': ['KLYUCHEPOVODNY', 'MECHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME MECHIK KLYUCHEPOVODNY
    '\U0001cfab': ['KLYUCHENEPOSTOYANNY', 'MECHIK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME MECHIK KLYUCHENEPOSTOYANNY
    '\U0001cfac': ['TRYASOGLASNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA TRYASOGLASNAYA
    '\U0001cfad': ['TRYASOPOVODNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA TRYASOPOVODNAYA
    '\U0001cfae': ['TRYASOSTRELNAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA TRYASOSTRELNAYA
    '\U0001cfaf': ['OSOKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME OSOKA
    '\U0001cfb0': ['OSOKA', 'SVETLAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME OSOKA SVETLAYA
    '\U0001cfb1': ['TRESVETLAYA', 'OSOKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME OSOKA TRESVETLAYA
    '\U0001cfb2': ['OSOKA', 'SVETLAYA', 'KRYUKOVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME OSOKA KRYUKOVAYA SVETLAYA
    '\U0001cfb3': ['OSOKA', 'SVETLAYA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME OSOKA KLYUCHEVAYA SVETLAYA
    '\U0001cfb4': ['NEPOSTOYANNAYA', 'OSOKA', 'KLYUCHEVAYA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME OSOKA KLYUCHEVAYA NEPOSTOYANNAYA
    '\U0001cfb5': ['KRYUKOVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA
    '\U0001cfb6': ['POVODNAYA', 'KRYUKOVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA POVODNAYA
    '\U0001cfb7': ['GROMNAYA', 'SINGLE', 'ZAPYATAYA', 'KRYUKOVAYA', 'STRELA', 'WITH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA GROMNAYA WITH SINGLE ZAPYATAYA
    '\U0001cfb8': ['SINGLE', 'GROMOPOVODNAYA', 'ZAPYATAYA', 'KRYUKOVAYA', 'STRELA', 'WITH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA GROMOPOVODNAYA WITH SINGLE ZAPYATAYA
    '\U0001cfb9': ['GROMNAYA', 'KRYUKOVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA GROMNAYA
    '\U0001cfba': ['GROMOPOVODNAYA', 'KRYUKOVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA GROMOPOVODNAYA
    '\U0001cfbb': ['GROMOPOVODNAYA', 'DOUBLE', 'ZAPYATAYA', 'KRYUKOVAYA', 'STRELA', 'WITH', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA GROMOPOVODNAYA WITH DOUBLE ZAPYATAYA
    '\U0001cfbc': ['GROMOKRYZHEVAYA', 'KRYUKOVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA GROMOKRYZHEVAYA
    '\U0001cfbd': ['GROMOKRYZHEVAYA', 'POVODNAYA', 'KRYUKOVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA GROMOKRYZHEVAYA POVODNAYA
    '\U0001cfbe': ['TRYASKA', 'KRYUKOVAYA', 'STRELA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME STRELA KRYUKOVAYA TRYASKA
    '\U0001cfbf': ['KUFISMA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME KUFISMA
    '\U0001cfc0': ['OBLAKO', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME OBLAKO
    '\U0001cfc1': ['DUDA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME DUDA
    '\U0001cfc2': ['NEMKA', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME NEMKA
    '\U0001cfc3': ['PAUK', 'ZNAMENNY', 'NEUME'],  # ZNAMENNY NEUME PAUK
    '𝄞': ['MUSICAL', 'CLEF', 'G', 'SYMBOL'],  # MUSICAL SYMBOL G CLEF
    '🅲': ['C', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER C
    '🅳': ['D', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER D
    '🅴': ['E', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER E
    '🅵': ['F', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER F
    '🅶': ['G', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER G
    '🅷': ['H', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER H
    '🅸': ['I', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER I
    '🅹': ['J', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER J
    '🅺': ['K', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER K
    '🅻': ['L', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER L
    '🅼': ['M', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER M
    '🅽': ['N', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER N
    '🆀': ['Q', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER Q
    '🆁': ['R', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER R
    '🆂': ['S', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER S
    '🆃': ['T', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER T
    '🆄': ['U', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER U
    '🆅': ['V', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER V
    '🆆': ['W', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER W
    '🆇': ['X', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER X
    '🆈': ['Y', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER Y
    '🆉': ['Z', 'CAPITAL', 'LETTER', 'LATIN', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED LATIN CAPITAL LETTER Z
    '🆋': ['IC', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED IC
    '🆌': ['PA', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED PA
    '🆍': ['SA', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED SA
    '🆏': ['WC', 'NEGATIVE', 'SQUARED'],  # NEGATIVE SQUARED WC
    '🆛': ['D', 'THREE', 'SQUARED'],  # SQUARED THREE D
    '🆜': ['SECOND', 'SCREEN', 'SQUARED'],  # SQUARED SECOND SCREEN
    '🆝': ['TWO', 'K', 'SQUARED'],  # SQUARED TWO K
    '🆞': ['K', 'FOUR', 'SQUARED'],  # SQUARED FOUR K
    '🆟': ['K', 'EIGHT', 'SQUARED'],  # SQUARED EIGHT K
    '🆠': ['FIVE', 'POINT', 'ONE', 'SQUARED'],  # SQUARED FIVE POINT ONE
    '🆡': ['SEVEN', 'POINT', 'ONE', 'SQUARED'],  # SQUARED SEVEN POINT ONE
    '🆢': ['TWENTY-TWO', 'TWO', 'POINT', 'SQUARED'],  # SQUARED TWENTY-TWO POINT TWO
    '🆣': ['SIXTY', 'P', 'SQUARED'],  # SQUARED SIXTY P
    '🆤': ['HUNDRED', 'TWENTY', 'P', 'ONE', 'SQUARED'],  # SQUARED ONE HUNDRED TWENTY P
    '🆥': ['D', 'SMALL', 'LETTER', 'LATIN', 'SQUARED'],  # SQUARED LATIN SMALL LETTER D
    '🆦': ['HC', 'SQUARED'],  # SQUARED HC
    '🆧': ['HDR', 'SQUARED'],  # SQUARED HDR
    '🆨': ['HI-RES', 'SQUARED'],  # SQUARED HI-RES
    '🆩': ['LOSSLESS', 'SQUARED'],  # SQUARED LOSSLESS
    '🆪': ['SHV', 'SQUARED'],  # SQUARED SHV
    '🆫': ['UHD', 'SQUARED'],  # SQUARED UHD
    '🆬': ['VOD', 'SQUARED'],  # SQUARED VOD
    '🕀': ['POMMEE', 'CIRCLED', 'CROSS'],  # CIRCLED CROSS POMMEE
    '🕂': ['POMMEE', 'CROSS'],  # CROSS POMMEE
    '🕃': ['NOTCHED', 'SEMICIRCLE', 'DOTS', 'THREE', 'LEFT', 'WITH'],  # NOTCHED LEFT SEMICIRCLE WITH THREE DOTS
    '🕄': ['NOTCHED', 'SEMICIRCLE', 'DOTS', 'THREE', 'RIGHT', 'WITH'],  # NOTCHED RIGHT SEMICIRCLE WITH THREE DOTS
    '🙐': ['LEAF', 'POINTING', 'WEST', 'NORTH'],  # NORTH WEST POINTING LEAF
    '🙑': ['LEAF', 'POINTING', 'WEST', 'SOUTH'],  # SOUTH WEST POINTING LEAF
    '🙒': ['LEAF', 'POINTING', 'NORTH', 'EAST'],  # NORTH EAST POINTING LEAF
    '🙓': ['LEAF', 'POINTING', 'SOUTH', 'EAST'],  # SOUTH EAST POINTING LEAF
    '🙬': ['ROCKET', 'LEFTWARDS'],  # LEFTWARDS ROCKET
    '🙭': ['ROCKET', 'UPWARDS'],  # UPWARDS ROCKET
    '🙮': ['ROCKET', 'RIGHTWARDS'],  # RIGHTWARDS ROCKET
    '🙯': ['ROCKET', 'DOWNWARDS'],  # DOWNWARDS ROCKET
    '🙼': ['VERY', 'SOLIDUS', 'HEAVY'],  # VERY HEAVY SOLIDUS
    '🙽': ['REVERSE', 'VERY', 'SOLIDUS', 'HEAVY'],  # VERY HEAVY REVERSE SOLIDUS
    '🞇': ['CIRCLE', 'WHITE', 'HEAVY'],  # HEAVY WHITE CIRCLE
    '🞬': ['SALTIRE', 'HEAVY'],  # HEAVY SALTIRE
    '🞲': ['SPOKED', 'FIVE', 'ASTERISK', 'HEAVY'],  # HEAVY FIVE SPOKED ASTERISK
    '🞸': ['SPOKED', 'SIX', 'ASTERISK', 'HEAVY'],  # HEAVY SIX SPOKED ASTERISK
    '🞾': ['SPOKED', 'EIGHT', 'ASTERISK', 'HEAVY'],  # HEAVY EIGHT SPOKED ASTERISK
    '🟂': ['THREE', 'POINTED', 'STAR', 'BLACK'],  # THREE POINTED BLACK STAR
    '🟆': ['FOUR', 'POINTED', 'STAR', 'BLACK'],  # FOUR POINTED BLACK STAR
    '🟊': ['FIVE', 'POINTED', 'STAR', 'HEAVY', 'BLACK'],  # HEAVY FIVE POINTED BLACK STAR
    '🟌': ['SIX', 'POINTED', 'STAR', 'HEAVY', 'BLACK'],  # HEAVY SIX POINTED BLACK STAR
    '🡄': ['LEFTWARDS', 'HEAVY', 'ARROW'],  # LEFTWARDS HEAVY ARROW
    '🡅': ['UPWARDS', 'HEAVY', 'ARROW'],  # UPWARDS HEAVY ARROW
    '🡆': ['RIGHTWARDS', 'HEAVY', 'ARROW'],  # RIGHTWARDS HEAVY ARROW
    '🡇': ['DOWNWARDS', 'HEAVY', 'ARROW'],  # DOWNWARDS HEAVY ARROW
    '🡸': ['BARB', 'WIDE-HEADED', 'LEFTWARDS', 'HEAVY', 'ARROW'],  # WIDE-HEADED LEFTWARDS HEAVY BARB ARROW
    '🡹': ['BARB', 'WIDE-HEADED', 'UPWARDS', 'HEAVY', 'ARROW'],  # WIDE-HEADED UPWARDS HEAVY BARB ARROW
    '🡺': ['BARB', 'WIDE-HEADED', 'RIGHTWARDS', 'HEAVY', 'ARROW'],  # WIDE-HEADED RIGHTWARDS HEAVY BARB ARROW
    '🡻': ['BARB', 'WIDE-HEADED', 'DOWNWARDS', 'HEAVY', 'ARROW'],  # WIDE-HEADED DOWNWARDS HEAVY BARB ARROW
    '🡼': ['BARB', 'WIDE-HEADED', 'WEST', 'NORTH', 'HEAVY', 'ARROW'],  # WIDE-HEADED NORTH WEST HEAVY BARB ARROW
    '🡽': ['BARB', 'WIDE-HEADED', 'NORTH', 'EAST', 'HEAVY', 'ARROW'],  # WIDE-HEADED NORTH EAST HEAVY BARB ARROW
    '🡾': ['BARB', 'WIDE-HEADED', 'SOUTH', 'EAST', 'HEAVY', 'ARROW'],  # WIDE-HEADED SOUTH EAST HEAVY BARB ARROW
    '🡿': ['BARB', 'WIDE-HEADED', 'WEST', 'SOUTH', 'HEAVY', 'ARROW'],  # WIDE-HEADED SOUTH WEST HEAVY BARB ARROW
    '🤻': ['MODERN', 'PENTATHLON'],  # MODERN PENTATHLON
    '🮕': ['CHECKER', 'BOARD', 'FILL'],  # CHECKER BOARD FILL
    '🮰': ['ARROWHEAD-SHAPED', 'POINTER'],  # ARROWHEAD-SHAPED POINTER
    '🮱': ['CHECK', 'INVERSE', 'MARK'],  # INVERSE CHECK MARK
    '🮲': ['RUNNING', 'MAN', 'HALF', 'LEFT'],  # LEFT HALF RUNNING MAN
    '🮳': ['RUNNING', 'MAN', 'HALF', 'RIGHT'],  # RIGHT HALF RUNNING MAN
    '🮴': ['INVERSE', 'TIP', 'LEFTWARDS', 'DOWNWARDS', 'WITH', 'ARROW'],  # INVERSE DOWNWARDS ARROW WITH TIP LEFTWARDS
    '🮹': ['FOLDER', 'HALF', 'LEFT'],  # LEFT HALF FOLDER
    '🮺': ['FOLDER', 'HALF', 'RIGHT'],  # RIGHT HALF FOLDER
    '🮻': ['VOIDED', 'GREEK', 'CROSS'],  # VOIDED GREEK CROSS
    '🮼': ['DOT', 'OPEN', 'RIGHT', 'SQUARED'],  # RIGHT OPEN SQUARED DOT
    '🮽': ['DIAGONAL', 'CROSS', 'NEGATIVE'],  # NEGATIVE DIAGONAL CROSS
    '🮾': ['MIDDLE', 'CENTRE', 'DIAGONAL', 'TO', 'LOWER', 'NEGATIVE', 'RIGHT'],  # NEGATIVE DIAGONAL MIDDLE RIGHT TO LOWER CENTRE
    '🮿': ['DIAGONAL', 'DIAMOND', 'NEGATIVE'],  # NEGATIVE DIAGONAL DIAMOND
    '🯀': ['ROUNDED', 'CORNERS', 'SALTIRE', 'WHITE', 'HEAVY', 'WITH'],  # WHITE HEAVY SALTIRE WITH ROUNDED CORNERS
    '🯁': ['THIRD', 'INDEX', 'POINTING', 'LEFT', 'WHITE', 'RIGHT'],  # LEFT THIRD WHITE RIGHT POINTING INDEX
    '🯂': ['MIDDLE', 'THIRD', 'INDEX', 'POINTING', 'WHITE', 'RIGHT'],  # MIDDLE THIRD WHITE RIGHT POINTING INDEX
    '🯃': ['THIRD', 'INDEX', 'POINTING', 'WHITE', 'RIGHT', 'RIGHT'],  # RIGHT THIRD WHITE RIGHT POINTING INDEX
    '🯅': ['STICK', 'FIGURE'],  # STICK FIGURE
    '🯆': ['ARMS', 'RAISED', 'STICK', 'FIGURE', 'WITH'],  # STICK FIGURE WITH ARMS RAISED
    '🯇': ['LEANING', 'STICK', 'FIGURE', 'LEFT'],  # STICK FIGURE LEANING LEFT
    '🯈': ['LEANING', 'STICK', 'FIGURE', 'RIGHT'],  # STICK FIGURE LEANING RIGHT
    '🯉': ['DRESS', 'STICK', 'FIGURE', 'WITH'],  # STICK FIGURE WITH DRESS
    '🯊': ['CHEVRON', 'UP-POINTING', 'WHITE'],  # WHITE UP-POINTING CHEVRON
}
